# %% [markdown]
# <a href="https://colab.research.google.com/github/bezymannyj83-sketch/Is-it-edible-berry/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models
from google.colab import files
import tensorflow as tf


dataset = tf.keras.utils.image_dataset_from_directory(
    "Is-it-edible-berry/data",
    image_size=(224,224),
    batch_size=32,
    validation_split=0.2,
    subset="both",
    seed=42
)

train_ds, val_ds = dataset

base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable = False

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.3),
    layers.Dense(5, activation="softmax")
])


model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)

model.save("berry_model.keras")

files.download("berry_model.keras")
print(train_ds.class_names)
# Out:
# Found 100 files belonging to 5 classes.
# Using 80 files for training.
# Using 20 files for validation.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.1750 - loss: 1.8540 - val_accuracy: 0.7500 - val_loss: 0.9671
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.5000 - loss: 1.1754 - val_accuracy: 0.8000 - val_loss: 0.7038
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.6625 - loss: 0.8249 - val_accuracy: 0.7500 - val_loss: 0.7310
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7125 - loss: 0.6733 - val_accuracy: 0.8500 - val_loss: 0.5247
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8625 - loss: 0.4765 - val_accuracy: 0.9500 - val_loss: 0.3988
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.8625 - loss: 0.4411 - val_accuracy: 0.9000 - val_loss: 0.3747
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.9625 - loss: 0.3131 - val_accuracy: 0.8500 - val_loss: 0.3708
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9250 - loss: 0.2981 - val_accuracy: 0.8000 - val_loss: 0.4027
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9250 - loss: 0.2647 - val_accuracy: 0.8500 - val_loss: 0.4166
# Epoch 10/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.8875 - loss: 0.2730 - val_accuracy: 0.8500 - val_loss: 0.3827
# ['blackberry', 'blueberry', 'cranberry', 'raspberry', 'strawberry']

# %%
# !git clone https://github.com/bezymannyj83-sketch/Is-it-edible-berry.git
# Out:
# Cloning into 'Is-it-edible-berry'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 146 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (146/146), 3.11 MiB | 28.43 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
