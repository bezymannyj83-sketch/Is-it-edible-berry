# %% [markdown]
# <a href="https://colab.research.google.com/github/bezymannyj83-sketch/Is-it-edible-berry/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models
from google.colab import files
import tensorflow as tf


dataset = tf.keras.utils.image_dataset_from_directory(
    "Is-it-edible-berry/data",
    image_size=(224,224),
    batch_size=32,
    validation_split=0.2,
    subset="both",
    seed=42
)

train_ds, val_ds = dataset

base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable = False

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.3),
    layers.Dense(5, activation="softmax")
])


model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)

model.save("berry_model.keras")

files.download("berry_model.keras")
print(train_ds.class_names)
# Out:
# Found 100 files belonging to 5 classes.
# Using 80 files for training.
# Using 20 files for validation.
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.2750 - loss: 1.7322 - val_accuracy: 0.5500 - val_loss: 0.8994
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.4875 - loss: 1.2310 - val_accuracy: 0.8500 - val_loss: 0.6724
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.6375 - loss: 0.9264 - val_accuracy: 0.6500 - val_loss: 0.8046
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7500 - loss: 0.7747 - val_accuracy: 0.6500 - val_loss: 0.5971
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.8125 - loss: 0.5320 - val_accuracy: 0.8500 - val_loss: 0.4488
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.8750 - loss: 0.4689 - val_accuracy: 0.8500 - val_loss: 0.4163
# Epoch 7/10
# ...

# %%
# !git clone https://github.com/bezymannyj83-sketch/Is-it-edible-berry.git
# Out:
# Cloning into 'Is-it-edible-berry'...
# remote: Enumerating objects: 185, done.
# remote: Counting objects: 100% (185/185), done.
# remote: Compressing objects: 100% (178/178), done.
# remote: Total 185 (delta 28), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (185/185), 21.08 MiB | 14.05 MiB/s, done.
# Resolving deltas: 100% (28/28), done.

# %%
import matplotlib.pyplot as plt
from google.colab import files
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

class_names = [
    'blackberry',
    'blueberry',
    'cranberry',
    'raspberry',
    'strawberry'
]

uploaded = files.upload()
img = image.load_img(list(uploaded.keys())[0], target_size=(224, 224))
model = tf.keras.models.load_model("berry_model.keras")
img_array = image.img_to_array(img)

img_array = np.expand_dims(img_array, axis=0)

img_array = preprocess_input(img_array)

prediction = model.predict(img_array, verbose=0)

confidence = np.max(prediction) * 100
print(prediction)

if confidence < 70:
    print("Несъедобная")
else:
    print("Съедобная")
# Out:
#      <input type="file" id="files-dfb74f44-a311-474d-b237-131dedfb64f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dfb74f44-a311-474d-b237-131dedfb64f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from google.colab import files

model = tf.keras.models.load_model("berry_model.keras")
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)
plt.figure(figsize=(10,5))

plt.plot(
    history.history['accuracy'],
    label='Train Accuracy'
)

plt.plot(
    history.history['val_accuracy'],
    label='Validation Accuracy'
)

plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.legend()

plt.show()

plt.figure(figsize=(10,5))

plt.plot(
    history.history['loss'],
    label='Train Loss'
)


plt.plot(
    history.history['val_loss'],
    label='Validation Loss'
)


plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.legend()
print(train_ds.class_names)

print(len(train_ds.class_names))
print(history.history.keys())

print(history.history['accuracy'][-1])
print(history.history['val_accuracy'][-1])

print(history.history['loss'][-1])
print(history.history['val_loss'][-1])

plt.show()
# Out:
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 26s 6s/step - accuracy: 0.9500 - loss: 0.2042 - val_accuracy: 0.9000 - val_loss: 0.3127
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.9500 - loss: 0.1895 - val_accuracy: 0.9000 - val_loss: 0.3051
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.9625 - loss: 0.1466 - val_accuracy: 0.7500 - val_loss: 0.3415
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9625 - loss: 0.1434 - val_accuracy: 0.7500 - val_loss: 0.3494
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - accuracy: 0.9500 - loss: 0.1670 - val_accuracy: 0.9000 - val_loss: 0.2928
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.9625 - loss: 0.1288 - val_accuracy: 0.8500 - val_loss: 0.3119
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.9625 - loss: 0.1734 - val_accuracy: 0.7500 - val_loss: 0.3945
# Epoch 8/10
# ...
